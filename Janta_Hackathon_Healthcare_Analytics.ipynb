# %% [markdown]
# # Problem Statement:
#
# Congratulations – you have been hired as Chief Data Scientist of MedCamp – a not for profit organization dedicated in making health conditions for working professionals better. MedCamp was started because the founders saw their family suffer due to bad work life balance and neglected health.
#
# MedCamp organizes health camps in several cities with low work life balance. They reach out to working people and ask them to register for these health camps. For those who attend, MedCamp provides them facility to undergo health checks or increase awareness by visiting various stalls (depending on the format of camp).
#
# MedCamp has conducted 65 such events over a period of 4 years and they see a high drop off between “Registration” and Number of people taking tests at the Camps. In last 4 years, they have stored data of ~110,000 registrations they have done.
#
# One of the huge costs in arranging these camps is the amount of inventory you need to carry. If you carry more than required inventory, you incur unnecessarily high costs. On the other hand, if you carry less than required inventory for conducting these medical checks, people end up having bad experience.
#
#
#
# The Process:
# 1. MedCamp employees / volunteers reach out to people and drive registrations.
#
# 2. During the camp, People who “ShowUp” either undergo the medical tests or visit stalls depending on the format of health camp.
#
#
# Other things to note:
# 1. Since this is a completely voluntary activity for the working professionals, MedCamp usually has little profile information about these people.
#
# 2. For a few camps, there was hardware failure, so some information about date and time of registration is lost.
#
# 3. MedCamp runs 3 formats of these camps. The first and second format provides people with an instantaneous health score. The third format provides information about several health issues through various awareness stalls.
#
# Favorable outcome:
# 1. For the first 2 formats, a favourable outcome is defined as getting a health_score, while in the third format it is defined as visiting at least a stall.
#
# 2. You need to predict the chances (probability) of having a favourable outcome.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-612009b8-349b-4402-8e75-1b78baa675be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-612009b8-349b-4402-8e75-1b78baa675be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data_Dictionary.xlsx to Data_Dictionary.xlsx
# Saving First_Health_Camp_Attended.csv to First_Health_Camp_Attended.csv
# Saving Health_Camp_Detail.csv to Health_Camp_Detail.csv
# Saving Patient_Profile.csv to Patient_Profile.csv
# Saving sample_submmission.csv to sample_submmission.csv
# Saving Second_Health_Camp_Attended.csv to Second_Health_Camp_Attended.csv
# Saving test_l0Auv8Q.csv to test_l0Auv8Q.csv
# Saving Third_Health_Camp_Attended.csv to Third_Health_Camp_Attended.csv
# Saving Train.csv to Train.csv

# %%
train_data = pd.read_csv("Train.csv")
first_health_camp_data = pd.read_csv("First_Health_Camp_Attended.csv")
health_camp_details = pd.read_csv("Health_Camp_Detail.csv")
second_health_camp_data = pd.read_csv("Second_Health_Camp_Attended.csv")
third_health_camp_data = pd.read_csv("Third_Health_Camp_Attended.csv")
patient_profile = pd.read_csv("Patient_Profile.csv")
test_data = pd.read_csv("test_l0Auv8Q.csv")

# %% [markdown]
# # Data Cleaning:

# %%
patient_profile.head()
# Out:
#    Patient_ID  Online_Follower  ...  City_Type  Employer_Category
# 0      516956                0  ...        NaN  Software Industry
# 1      507733                0  ...          H  Software Industry
# 2      508307                0  ...          D               BFSI
# 3      512612                0  ...          D          Education
# 4      521075                0  ...          H             Others
#
# [5 rows x 11 columns]

# %%
train = pd.merge(train_data, first_health_camp_data.drop('Unnamed: 4',axis = 1), how = 'left', on = ['Patient_ID','Health_Camp_ID'], indicator = "merge_1")
train = pd.merge(train, second_health_camp_data, how = 'left', on = ['Patient_ID','Health_Camp_ID'], indicator = "merge_2")
train = pd.merge(train, third_health_camp_data, how = 'left', on = ['Patient_ID','Health_Camp_ID'], indicator = "merge_3")
train = pd.merge(train, health_camp_details, how = 'left', on = ['Health_Camp_ID'], indicator = "merge_healthcamp")
train = pd.merge(train, patient_profile, how = 'left', on = ['Patient_ID'], indicator = "merge_patientprofile")

# %%
train
# Out:
#        Patient_ID  Health_Camp_ID  ...  Employer_Category  merge_patientprofile
# 0          489652            6578  ...                NaN                  both
# 1          507246            6578  ...             Others                  both
# 2          523729            6534  ...                NaN                  both
# 3          524931            6535  ...                NaN                  both
# 4          521364            6529  ...         Technology                  both
# ...           ...             ...  ...                ...                   ...
# 75273      500969            6539  ...                NaN                  both
# 75274      511952            6528  ...        Real Estate                  both
# 75275      521236            6554  ...  Software Industry                  both
# 75276      518817            6580  ...         Technology                  both
# 75277      511284            6555  ...                NaN                  both
#
# [75278 rows x 33 columns]

# %%
train['outcome']  = 0

# %%
train.loc[(train.merge_1 == "both") |
          (train.merge_2 == 'both') |
          (train.merge_3 == 'both') & (train.Number_of_stall_visited > 0),'outcome'] = 1

# %%
train.head()
# Out:
#    Patient_ID  Health_Camp_ID  ... merge_patientprofile  outcome
# 0      489652            6578  ...                 both        1
# 1      507246            6578  ...                 both        0
# 2      523729            6534  ...                 both        1
# 3      524931            6535  ...                 both        0
# 4      521364            6529  ...                 both        1
#
# [5 rows x 34 columns]

# %%
test = pd.merge(test_data, first_health_camp_data.drop('Unnamed: 4',axis = 1), how = 'left', on = ['Patient_ID','Health_Camp_ID'], indicator = "merge_1")
test = pd.merge(test, second_health_camp_data, how = 'left', on = ['Patient_ID','Health_Camp_ID'], indicator = "merge_2")
test = pd.merge(test, third_health_camp_data, how = 'left', on = ['Patient_ID','Health_Camp_ID'], indicator = "merge_3")
test = pd.merge(test, health_camp_details, how = 'left', on = ['Health_Camp_ID'], indicator = "merge_healthcamp")
test = pd.merge(test, patient_profile, how = 'left', on = ['Patient_ID'], indicator = "merge_patientprofile")

# %%
test.head()
# Out:
#    Patient_ID  Health_Camp_ID  ... Employer_Category  merge_patientprofile
# 0      505701            6548  ...               NaN                  both
# 1      500633            6584  ...        Consulting                  both
# 2      506945            6582  ...               NaN                  both
# 3      497447            6551  ...               NaN                  both
# 4      496446            6533  ...               NaN                  both
#
# [5 rows x 33 columns]

# %%
train.columns
# Out:
# Index(['Patient_ID', 'Health_Camp_ID', 'Registration_Date', 'Var1', 'Var2',
#        'Var3', 'Var4', 'Var5', 'Donation', 'Health_Score', 'merge_1',
#        'Health Score', 'merge_2', 'Number_of_stall_visited',
#        'Last_Stall_Visited_Number', 'merge_3', 'Camp_Start_Date',
#        'Camp_End_Date', 'Category1', 'Category2', 'Category3',
#        'merge_healthcamp', 'Online_Follower', 'LinkedIn_Shared',
#        'Twitter_Shared', 'Facebook_Shared', 'Income', 'Education_Score', 'Age',
#        'First_Interaction', 'City_Type', 'Employer_Category',
#        'merge_patientprofile', 'outcome'],
#       dtype='object')

# %%
date_cols = ['Registration_Date','Camp_Start_Date','Camp_End_Date','First_Interaction']

# %%
def to_date(df):
    for col in date_cols:
        if col in df.columns:
            df[col] = pd.to_datetime(df[col],format = "%d-%b-%y")
    return df

# %%
train = to_date(train)
test = to_date(test)

# %%
num_cols = ['Income', 'Education_Score', 'Age']

# %%
import pandas.api.types as ptypes
~(ptypes.is_numeric_dtype(train['Age']))
# Out:
# -1

# %%
def to_numeric(df):
    for col in df.columns:
        if (col in num_cols) & ~(ptypes.is_numeric_dtype(df[col])):
            df[col] = df[col].replace({"None":""})
            df[col] = pd.to_numeric(df[col], errors = 'coerce')
    return df

# %%
train = to_numeric(train)
test = to_numeric(test)

# %%
train.sort_values(['Patient_ID','Registration_Date'])
# Out:
#        Patient_ID  Health_Camp_ID  ... merge_patientprofile  outcome
# 69348      485679            6578  ...                 both        1
# 64479      485679            6555  ...                 both        0
# 6484       485680            6543  ...                 both        0
# 18999      485681            6580  ...                 both        0
# 2604       485681            6526  ...                 both        0
# ...           ...             ...  ...                  ...      ...
# 18124      528657            6531  ...                 both        1
# 32744      528657            6580  ...                 both        0
# 7632       528657            6526  ...                 both        0
# 24471      528657            6536  ...                 both        1
# 3369       528657            6555  ...                 both        0
#
# [75278 rows x 34 columns]

# %% [markdown]
# # Drop unnecessary columns:

# %%
cols = ['merge_1','merge_2','merge_3','merge_healthcamp','merge_patientprofile']

# %%
train.drop(cols,axis = 1,inplace = True)
test.drop(cols,axis = 1,inplace = True)

# %% [markdown]
# # Missing Imputations:

# %%
from sklearn.impute import SimpleImputer

# %%
train.isnull().sum()
# Out:
# Patient_ID                       0
# Health_Camp_ID                   0
# Registration_Date              334
# Var1                             0
# Var2                             0
# Var3                             0
# Var4                             0
# Var5                             0
# Donation                     69060
# Health_Score                 69060
# Health Score                 67459
# Number_of_stall_visited      68763
# Last_Stall_Visited_Number    68763
# Camp_Start_Date                  0
# Camp_End_Date                    0
# Category1                        0
# Category2                        0
# Category3                        0
# Online_Follower                  0
# LinkedIn_Shared                  0
# Twitter_Shared                   0
# Facebook_Shared                  0
# Income                       53546
# Education_Score              65345
# Age                          51612
# First_Interaction                0
# City_Type                    33208
# Employer_Category            60075
# outcome                          0
# dtype: int64

# %% [markdown]
# # Mean Imputation:

# %%
mean_impute_cols = ['Age']
impute_mean = SimpleImputer(strategy = 'mean')
impute_mean.fit(train[mean_impute_cols])
train[mean_impute_cols] = impute_mean.transform(train[mean_impute_cols])
test[mean_impute_cols] = impute_mean.transform(test[mean_impute_cols])

# %% [markdown]
# # Frequent Imputation:

# %%
freq_impute_cols = ['Income', 'Education_Score', 'City_Type', 'Employer_Category']

# %%
impute_freq = SimpleImputer(strategy = 'most_frequent')
impute_freq.fit(train[freq_impute_cols])
train[freq_impute_cols] = impute_freq.transform(train[freq_impute_cols])
test[freq_impute_cols] = impute_freq.transform(test[freq_impute_cols])

# %% [markdown]
# # Zero Imputation:

# %%
zero_impute_cols = ['Donation', 'Health_Score', 'Health Score', 'Number_of_stall_visited', 'Last_Stall_Visited_Number']

# %%
train[zero_impute_cols] = train[zero_impute_cols].fillna(0)
test[zero_impute_cols] = test[zero_impute_cols].fillna(0)

# %% [markdown]
# # Missing Date Imputation:

# %%
def date_impute(df):
    midpoint = df['Camp_Start_Date'] + (df['Camp_End_Date'] - df['Camp_Start_Date'])/2
    df['Registration_Date'] = df['Registration_Date'].fillna(midpoint)
    df['Registration_Date'] = pd.to_datetime(df['Registration_Date'], format = "%Y-%m-%d")
    return df

# %%
train = date_impute(train)
test = date_impute(test)

# %% [markdown]
# # Feature engineering:

# %% [markdown]
# # 1.Duration of camp:

# %%
train['camp_duration'] = (train['Camp_End_Date'] - train['Camp_Start_Date']).dt.days
test['camp_duration'] = (test['Camp_End_Date'] - test['Camp_Start_Date']).dt.days

# %% [markdown]
# # 2.Registered before/after start of camp:

# %%
train['reg_start_diff'] = (train['Camp_Start_Date'] - train['Registration_Date']).dt.days
test['reg_start_diff'] = (test['Camp_Start_Date'] - test['Registration_Date']).dt.days

# %% [markdown]
# # 3.Days left for camp end:

# %%
train['days_for_camp_end'] = (train['Registration_Date'] - train['Camp_End_Date']).dt.days
test['days_for_camp_end'] = (test['Registration_Date'] - test['Camp_End_Date']).dt.days

# %% [markdown]
# # 4.Point in camp:

# %%
train['point_in_camp'] = 1 - train['days_for_camp_end']/train['camp_duration']
test['point_in_camp'] = 1 - test['days_for_camp_end']/test['camp_duration']

# %% [markdown]
# # Days since first and last interaction:

# %%
train['is_train'] = True
test['is_train'] = False
all_data = pd.concat([train,test])
all_data = all_data.reset_index(drop=True)
all_data = all_data.sort_values(['Patient_ID', 'Registration_Date'])
all_data = all_data.reset_index(drop=True)
patient_wise_visits = all_data.loc[:,['Patient_ID','Registration_Date']]
patient_wise_visits = patient_wise_visits.drop_duplicates()
patient_wise_visits = patient_wise_visits.reset_index(drop=True)
patient_wise_visits['Last_Interaction'] = patient_wise_visits.groupby('Patient_ID')['Registration_Date'].shift()
all_data = pd.merge(all_data,patient_wise_visits,on=['Patient_ID', 'Registration_Date'],how='left')
all_data.loc[all_data['Last_Interaction'].isna(),'Last_Interaction'] = all_data['First_Interaction']
all_data['days_since_first_interaction'] = (all_data['Registration_Date'] - all_data['First_Interaction']).dt.days
all_data['days_since_last_interaction'] = (all_data['Registration_Date'] - all_data['Last_Interaction']).dt.days

# %% [markdown]
# # 6.Historic Features:

# %%
import sqlite3
#Make the db in memory
conn = sqlite3.connect(':memory:')
#write the tables
all_data.to_sql('all_data', conn, index=False)

qry = '''
        select a.Patient_ID, a.Registration_Date,
        count(b.Health_Camp_ID) as prev_registration_count,
        sum(b.Outcome) / count(b.Health_Camp_ID) as prev_response_rate,
        sum(case when b.Category2 = 'First' then b.Outcome else NULL end)/
        count( case when b.Category2 = 'First' then b.Health_Camp_ID else NULL end) as prev_first_response_rate,
        sum(case when b.Category2 = 'Second' then b.Outcome else NULL end)/
        count( case when b.Category2 = 'Second' then b.Health_Camp_ID else NULL end) as prev_second_response_rate,
        sum(case when b.Category2 = 'Third' then b.Outcome else NULL end)/
        count( case when b.Category2 = 'Third' then b.Health_Camp_ID else NULL end) as prev_third_response_rate,
        sum(b.Donation) as prev_donation,
        avg(case when b.Category2 = 'First' then b.Donation else NULL end) as prev_donation_avg,
        avg(case when b.Category2 = 'First' then b.Health_Score else NULL end) as prev_avg_health_score1,
        avg(case when b.Category2 = 'Second' then b.[Health Score] else NULL end) as prev_avg_health_score2,
        sum(b.Number_of_stall_visited) as prev_stall_count,
        avg(case when b.Category2 = 'Third' then b.Number_of_stall_visited else NULL end) as prev_stall_count_avg,
        count(distinct b.Last_Stall_Visited_Number) as prev_distinct_stalls
        from all_data as a left join all_data as b 
        on a.Patient_ID = b.Patient_ID 
        and b.Registration_Date < a.Registration_Date 
        group by a.Patient_ID, a.Registration_Date
      '''
patient_history = pd.read_sql_query(qry, conn)
patient_history['Registration_Date'] = pd.to_datetime(patient_history['Registration_Date'], format='%Y-%m-%d')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
all_data = pd.merge(all_data,patient_history,on=['Patient_ID','Registration_Date'],how='left')

# %% [markdown]
# # Missing imputation for new features:

# %%
new_feat = ['prev_response_rate', 'prev_first_response_rate', 'prev_second_response_rate', 'prev_third_response_rate',
           'prev_donation', 'prev_donation_avg', 'prev_avg_health_score1', 'prev_avg_health_score2', 'prev_stall_count',
           'prev_stall_count_avg']
all_data[new_feat] = all_data[new_feat].fillna(-999)

# %%
train_final_data = all_data.loc[all_data['is_train']==True]
test_final_data = all_data.loc[all_data['is_train']==False]

# %% [markdown]
# # Constants:

# %%
ID1 = 'Patient_ID'
ID2 = 'Health_Camp_ID'
target = 'outcome'
date_columns = ['Registration_Date', 'Camp_Start_Date', 'Camp_End_Date', 'First_Interaction']
discrete_columns = ['Var1', 'Var2', 'Var3', 'Var4', 'Var5', 'Category1', 'Category2', 'Category3', 'Online_Follower', 
                   'LinkedIn_Shared', 'Twitter_Shared', 'Facebook_Shared', 'City_Type', 'Employer_Category']
ignore_cols = [ID1, ID2, target, 'Registration_Date', 'Camp_Start_Date', 'Camp_End_Date', 'First_Interaction', 
               'Last_Interaction', 'Donation', 'Health_Score', 'Health Score', 'Number_of_stall_visited', 
               'Last_Stall_Visited_Number','is_train']

# %%
random_state = 1234

# %%
should_ohe = True
should_scale = True

# %% [markdown]
# # Scaling:

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import FunctionTransformer

# %%
if should_scale:
    for col in train_final_data.columns:
        if (col != target) and (col != ID1) and (col != ID2) and (col not in date_columns) and (col not in discrete_columns) and (col not in ignore_cols):
            mms = MinMaxScaler()
            ss = StandardScaler()
            rs = RobustScaler()
            pt = PowerTransformer()
            ft_log = FunctionTransformer(np.log)
            
            train_final_data[f"{col}_MMS"] = mms.fit_transform(train_final_data[[col]])
            test_final_data[f"{col}_MMS"] = mms.transform(test_final_data[[col]])
            
            train_final_data[f"{col}_SS"] = ss.fit_transform(train_final_data[[col]])
            test_final_data[f"{col}_SS"] = ss.transform(test_final_data[[col]])
            
            train_final_data[f"{col}_RS"] = rs.fit_transform(train_final_data[[col]])
            test_final_data[f"{col}_RS"] = rs.transform(test_final_data[[col]])
            
            train_final_data[f"{col}_PT"] = pt.fit_transform(train_final_data[[col]])
            test_final_data[f"{col}_PT"] = pt.transform(test_final_data[[col]])
            
#             train_final_data[f"{col}_FT_log"] = ft_log.fit_transform(train_final_data[[col]])
#             test_final_data[f"{col}_FT_log"] = ft_log.transform(test_final_data[[col]])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_data.py:2982: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_data.py:2982: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_data.py:2982: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_data.py:2982: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_data.py:2982: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_data.py:2982: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_data.py:2982: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # One hot encoding:

# %%
cols_for_ohe = ['Category1', 'Category2', 'City_Type', 'Employer_Category']

# %%
train_final_data = pd.concat([train_final_data.drop(cols_for_ohe,axis=1),pd.get_dummies(train_final_data[cols_for_ohe])],axis=1)
test_final_data = pd.concat([test_final_data.drop(cols_for_ohe,axis=1),pd.get_dummies(test_final_data[cols_for_ohe])],axis=1)

# %% [markdown]
# # Test train split:

# %%
from sklearn.model_selection import train_test_split

# %%
ignore_cols_train = [ID1, ID2, target, 'Registration_Date', 'Camp_Start_Date', 'Camp_End_Date', 'First_Interaction', 
               'Last_Interaction', 'Donation', 'Health_Score', 'Health Score', 'Number_of_stall_visited', 
               'Last_Stall_Visited_Number','is_train','Category2_B']
ignore_cols = [ID1, ID2, target, 'Registration_Date', 'Camp_Start_Date', 'Camp_End_Date', 'First_Interaction', 
               'Last_Interaction', 'Donation', 'Health_Score', 'Health Score', 'Number_of_stall_visited', 
               'Last_Stall_Visited_Number','is_train']
X, y = train_final_data.drop(ignore_cols_train, axis=1), train_final_data[target]
X_test = test_final_data.drop(ignore_cols, axis=1)

# %%
set(X.columns) - set(X_test.columns)
# Out:
# set()

# %%
X_test.shape
# Out:
# (35249, 147)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.30, random_state=random_state)

# %% [markdown]
# # Base Models:

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb
from sklearn.metrics import f1_score, auc, confusion_matrix, roc_curve, roc_auc_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import plot_confusion_matrix

# %%
n_esitmators = 1000
classifiers = {
    "DT": DecisionTreeClassifier(),
    "RF": RandomForestClassifier(n_estimators=n_esitmators, random_state=random_state),
    "GBM": GradientBoostingClassifier(n_estimators=n_esitmators, random_state=random_state),
    "GBM_ES": GradientBoostingClassifier(n_estimators=n_esitmators, validation_fraction=0.2, 
                                         n_iter_no_change=5,tol=0.01,random_state=random_state)
}

# %% [markdown]
# # Prepare learning rate shrinkage:

# %%
def learning_rate_010_decay_power_099(current_iter):
    base_learning_rate = 0.1
    lr = base_learning_rate  * np.power(.99, current_iter)
    return lr if lr > 1e-3 else 1e-3

def learning_rate_010_decay_power_0995(current_iter):
    base_learning_rate = 0.1
    lr = base_learning_rate  * np.power(.995, current_iter)
    return lr if lr > 1e-3 else 1e-3

def learning_rate_005_decay_power_099(current_iter):
    base_learning_rate = 0.05
    lr = base_learning_rate  * np.power(.99, current_iter)
    return lr if lr > 1e-3 else 1e-3

# %% [markdown]
# Use test subset for early stopping criterion

# %%
import lightgbm as lgb
fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [(X_val,y_val)],
            'eval_names': ['valid'],
            #'callbacks': [lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_099)],
            'verbose': 100,
            'categorical_feature': 'auto'}

# %% [markdown]
# Set up HyperParameter search

# %%
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

# %%
#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 100

import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
clf = lgb.LGBMClassifier(max_depth=-1, random_state=314, silent=True, metric='None', n_jobs=4, n_estimators=5000)
gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='roc_auc',
    cv=3,
    refit=True,
    random_state=314,
    verbose=True)

# %%
gs.fit(X_train, y_train, **fit_params)
print('Best score reached: {} with params: {} '.format(gs.best_score_, gs.best_params_))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864678
# [200]	valid's auc: 0.866965
# [300]	valid's auc: 0.867963
# [400]	valid's auc: 0.868569
# Early stopping, best iteration is:
# [422]	valid's auc: 0.868665
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864568
# [200]	valid's auc: 0.867167
# [300]	valid's auc: 0.868111
# [400]	valid's auc: 0.868567
# [500]	valid's auc: 0.869049
# [600]	valid's auc: 0.869238
# Early stopping, best iteration is:
# [579]	valid's auc: 0.869242
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864532
# [200]	valid's auc: 0.86697
# [300]	valid's auc: 0.867778
# [400]	valid's auc: 0.86841
# Early stopping, best iteration is:
# [445]	valid's auc: 0.868672
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.854943
# Early stopping, best iteration is:
# [111]	valid's auc: 0.855164
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.854337
# Early stopping, best iteration is:
# [114]	valid's auc: 0.854467
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.853869
# Early stopping, best iteration is:
# [112]	valid's auc: 0.854096
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.862754
# [200]	valid's auc: 0.864971
# [300]	valid's auc: 0.865822
# [400]	valid's auc: 0.866214
# [500]	valid's auc: 0.866608
# [600]	valid's auc: 0.866914
# [700]	valid's auc: 0.867258
# Early stopping, best iteration is:
# [694]	valid's auc: 0.867291
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.862208
# [200]	valid's auc: 0.864533
# [300]	valid's auc: 0.865462
# [400]	valid's auc: 0.866195
# [500]	valid's auc: 0.866709
# [600]	valid's auc: 0.866933
# Early stopping, best iteration is:
# [606]	valid's auc: 0.866985
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.862263
# [200]	valid's auc: 0.864244
# [300]	valid's auc: 0.865283
# [400]	valid's auc: 0.865613
# [500]	valid's auc: 0.866278
# Early stopping, best iteration is:
# [501]	valid's auc: 0.866307
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.855309
# Early stopping, best iteration is:
# [126]	valid's auc: 0.85562
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.854405
# Early stopping, best iteration is:
# [120]	valid's auc: 0.85477
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.853546
# Early stopping, best iteration is:
# [120]	valid's auc: 0.853899
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.861504
# [200]	valid's auc: 0.864121
# [300]	valid's auc: 0.865213
# [400]	valid's auc: 0.865957
# [500]	valid's auc: 0.866346
# [600]	valid's auc: 0.866664
# [700]	valid's auc: 0.867047
# [800]	valid's auc: 0.867372
# [900]	valid's auc: 0.867524
# [1000]	valid's auc: 0.867871
# Early stopping, best iteration is:
# [994]	valid's auc: 0.867888
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.860676
# [200]	valid's auc: 0.863677
# [300]	valid's auc: 0.864828
# [400]	valid's auc: 0.865585
# [500]	valid's auc: 0.865962
# [600]	valid's auc: 0.866411
# [700]	valid's auc: 0.866623
# [800]	valid's auc: 0.866916
# Early stopping, best iteration is:
# [840]	valid's auc: 0.867121
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.861058
# [200]	valid's auc: 0.863707
# [300]	valid's auc: 0.864974
# [400]	valid's auc: 0.86579
# [500]	valid's auc: 0.866322
# [600]	valid's auc: 0.866839
# [700]	valid's auc: 0.867406
# [800]	valid's auc: 0.867663
# Early stopping, best iteration is:
# [850]	valid's auc: 0.867895
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.867869
# [200]	valid's auc: 0.869863
# [300]	valid's auc: 0.870598
# [400]	valid's auc: 0.870981
# [500]	valid's auc: 0.871234
# Early stopping, best iteration is:
# [470]	valid's auc: 0.871259
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.867266
# [200]	valid's auc: 0.869184
# [300]	valid's auc: 0.869946
# Early stopping, best iteration is:
# [342]	valid's auc: 0.870002
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.8675
# [200]	valid's auc: 0.869266
# [300]	valid's auc: 0.870185
# Early stopping, best iteration is:
# [334]	valid's auc: 0.870278
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866363
# [200]	valid's auc: 0.868359
# [300]	valid's auc: 0.86949
# [400]	valid's auc: 0.870309
# [500]	valid's auc: 0.870745
# Early stopping, best iteration is:
# [527]	valid's auc: 0.870908
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.865995
# [200]	valid's auc: 0.868195
# [300]	valid's auc: 0.869334
# Early stopping, best iteration is:
# [345]	valid's auc: 0.869801
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866004
# [200]	valid's auc: 0.868519
# [300]	valid's auc: 0.869499
# [400]	valid's auc: 0.870365
# Early stopping, best iteration is:
# [386]	valid's auc: 0.870398
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866844
# [200]	valid's auc: 0.869442
# [300]	valid's auc: 0.870375
# [400]	valid's auc: 0.871034
# [500]	valid's auc: 0.87154
# [600]	valid's auc: 0.871763
# [700]	valid's auc: 0.871878
# Early stopping, best iteration is:
# [673]	valid's auc: 0.871901
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866201
# [200]	valid's auc: 0.868375
# [300]	valid's auc: 0.869771
# [400]	valid's auc: 0.870434
# Early stopping, best iteration is:
# [423]	valid's auc: 0.870577
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866851
# [200]	valid's auc: 0.868876
# [300]	valid's auc: 0.869767
# [400]	valid's auc: 0.870217
# [500]	valid's auc: 0.870544
# Early stopping, best iteration is:
# [514]	valid's auc: 0.870565
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.860724
# [200]	valid's auc: 0.863495
# [300]	valid's auc: 0.864622
# [400]	valid's auc: 0.86543
# [500]	valid's auc: 0.865731
# [600]	valid's auc: 0.866017
# [700]	valid's auc: 0.866284
# [800]	valid's auc: 0.866654
# [900]	valid's auc: 0.866929
# [1000]	valid's auc: 0.867231
# Early stopping, best iteration is:
# [1002]	valid's auc: 0.867247
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.860415
# [200]	valid's auc: 0.863314
# [300]	valid's auc: 0.864232
# [400]	valid's auc: 0.864905
# [500]	valid's auc: 0.865326
# [600]	valid's auc: 0.865732
# [700]	valid's auc: 0.86607
# Early stopping, best iteration is:
# [686]	valid's auc: 0.86609
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.860423
# [200]	valid's auc: 0.863008
# [300]	valid's auc: 0.86427
# [400]	valid's auc: 0.864688
# [500]	valid's auc: 0.865343
# [600]	valid's auc: 0.865913
# [700]	valid's auc: 0.866237
# [800]	valid's auc: 0.86649
# [900]	valid's auc: 0.866624
# Early stopping, best iteration is:
# [901]	valid's auc: 0.866628
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.859628
# Early stopping, best iteration is:
# [151]	valid's auc: 0.860492
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.858475
# Early stopping, best iteration is:
# [157]	valid's auc: 0.859391
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.858577
# [200]	valid's auc: 0.859816
# Early stopping, best iteration is:
# [171]	valid's auc: 0.859816
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.856232
# Early stopping, best iteration is:
# [105]	valid's auc: 0.856311
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.855226
# Early stopping, best iteration is:
# [107]	valid's auc: 0.85537
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.854659
# Early stopping, best iteration is:
# [113]	valid's auc: 0.854818
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.867206
# [200]	valid's auc: 0.869016
# [300]	valid's auc: 0.86982
# Early stopping, best iteration is:
# [356]	valid's auc: 0.870124
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.867051
# [200]	valid's auc: 0.868498
# [300]	valid's auc: 0.869237
# [400]	valid's auc: 0.869481
# Early stopping, best iteration is:
# [426]	valid's auc: 0.869569
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866364
# [200]	valid's auc: 0.867987
# [300]	valid's auc: 0.868755
# Early stopping, best iteration is:
# [311]	valid's auc: 0.868807
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.865547
# [200]	valid's auc: 0.867047
# [300]	valid's auc: 0.868251
# Early stopping, best iteration is:
# [351]	valid's auc: 0.868506
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.86512
# [200]	valid's auc: 0.866956
# [300]	valid's auc: 0.867969
# Early stopping, best iteration is:
# [338]	valid's auc: 0.868123
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.865513
# [200]	valid's auc: 0.867278
# [300]	valid's auc: 0.868001
# [400]	valid's auc: 0.868377
# Early stopping, best iteration is:
# [371]	valid's auc: 0.868377
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.841819
# [200]	valid's auc: 0.845839
# [300]	valid's auc: 0.848055
# [400]	valid's auc: 0.84954
# [500]	valid's auc: 0.850738
# [600]	valid's auc: 0.851505
# [700]	valid's auc: 0.852176
# [800]	valid's auc: 0.852754
# [900]	valid's auc: 0.85317
# [1000]	valid's auc: 0.853607
# [1100]	valid's auc: 0.853913
# [1200]	valid's auc: 0.854216
# [1300]	valid's auc: 0.854417
# [1400]	valid's auc: 0.854646
# [1500]	valid's auc: 0.854807
# [1600]	valid's auc: 0.854946
# [1700]	valid's auc: 0.855078
# [1800]	valid's auc: 0.8552
# [1900]	valid's auc: 0.855316
# [2000]	valid's auc: 0.855436
# [2100]	valid's auc: 0.855537
# Early stopping, best iteration is:
# [2108]	valid's auc: 0.855553
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866581
# [200]	valid's auc: 0.868652
# [300]	valid's auc: 0.86968
# [400]	valid's auc: 0.870203
# [500]	valid's auc: 0.870676
# Early stopping, best iteration is:
# [485]	valid's auc: 0.870746
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.865476
# [200]	valid's auc: 0.868009
# [300]	valid's auc: 0.868942
# [400]	valid's auc: 0.869573
# Early stopping, best iteration is:
# [451]	valid's auc: 0.869743
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.865345
# [200]	valid's auc: 0.868133
# Early stopping, best iteration is:
# [225]	valid's auc: 0.868255
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866515
# [200]	valid's auc: 0.868326
# [300]	valid's auc: 0.868997
# Early stopping, best iteration is:
# [323]	valid's auc: 0.869149
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.865386
# [200]	valid's auc: 0.867331
# [300]	valid's auc: 0.868214
# [400]	valid's auc: 0.868634
# Early stopping, best iteration is:
# [389]	valid's auc: 0.868636
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866022
# [200]	valid's auc: 0.867922
# [300]	valid's auc: 0.868482
# Early stopping, best iteration is:
# [355]	valid's auc: 0.86872
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.855076
# Early stopping, best iteration is:
# [120]	valid's auc: 0.855284
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.854891
# Early stopping, best iteration is:
# [119]	valid's auc: 0.855096
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.853862
# Early stopping, best iteration is:
# [139]	valid's auc: 0.85425
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.867789
# [200]	valid's auc: 0.868697
# [300]	valid's auc: 0.869426
# Early stopping, best iteration is:
# [301]	valid's auc: 0.869478
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.867529
# [200]	valid's auc: 0.869239
# Early stopping, best iteration is:
# [204]	valid's auc: 0.869292
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.867436
# [200]	valid's auc: 0.868974
# Early stopping, best iteration is:
# [246]	valid's auc: 0.869139
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.86327
# [200]	valid's auc: 0.8652
# [300]	valid's auc: 0.866215
# [400]	valid's auc: 0.86698
# [500]	valid's auc: 0.867424
# [600]	valid's auc: 0.867723
# [700]	valid's auc: 0.867919
# [800]	valid's auc: 0.868063
# Early stopping, best iteration is:
# [822]	valid's auc: 0.868128
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.862726
# [200]	valid's auc: 0.864867
# [300]	valid's auc: 0.865965
# [400]	valid's auc: 0.866401
# [500]	valid's auc: 0.866814
# [600]	valid's auc: 0.867316
# [700]	valid's auc: 0.867533
# [800]	valid's auc: 0.86794
# Early stopping, best iteration is:
# [804]	valid's auc: 0.867949
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.862561
# [200]	valid's auc: 0.864804
# [300]	valid's auc: 0.865719
# [400]	valid's auc: 0.866065
# [500]	valid's auc: 0.866509
# [600]	valid's auc: 0.866877
# [700]	valid's auc: 0.867088
# Early stopping, best iteration is:
# [763]	valid's auc: 0.867256
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.865185
# [200]	valid's auc: 0.866928
# [300]	valid's auc: 0.868066
# [400]	valid's auc: 0.868626
# Early stopping, best iteration is:
# [427]	valid's auc: 0.868722
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864536
# [200]	valid's auc: 0.866463
# [300]	valid's auc: 0.867278
# [400]	valid's auc: 0.867846
# Early stopping, best iteration is:
# [408]	valid's auc: 0.867949
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.863506
# [200]	valid's auc: 0.865467
# [300]	valid's auc: 0.86649
# [400]	valid's auc: 0.866937
# Early stopping, best iteration is:
# [436]	valid's auc: 0.867104
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864224
# [200]	valid's auc: 0.8664
# [300]	valid's auc: 0.867292
# [400]	valid's auc: 0.867632
# Early stopping, best iteration is:
# [379]	valid's auc: 0.867661
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.85933
# Early stopping, best iteration is:
# [150]	valid's auc: 0.860287
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.858548
# Early stopping, best iteration is:
# [141]	valid's auc: 0.859338
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.858338
# Early stopping, best iteration is:
# [152]	valid's auc: 0.85913
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.863122
# [200]	valid's auc: 0.865441
# [300]	valid's auc: 0.866343
# [400]	valid's auc: 0.866828
# [500]	valid's auc: 0.867175
# Early stopping, best iteration is:
# [484]	valid's auc: 0.867225
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.862212
# [200]	valid's auc: 0.864594
# [300]	valid's auc: 0.865393
# [400]	valid's auc: 0.866105
# [500]	valid's auc: 0.866563
# Early stopping, best iteration is:
# [548]	valid's auc: 0.866795
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.862474
# [200]	valid's auc: 0.864884
# [300]	valid's auc: 0.865673
# Early stopping, best iteration is:
# [365]	valid's auc: 0.866207
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866846
# [200]	valid's auc: 0.868889
# [300]	valid's auc: 0.869531
# Early stopping, best iteration is:
# [282]	valid's auc: 0.869557
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866606
# [200]	valid's auc: 0.868381
# [300]	valid's auc: 0.869277
# Early stopping, best iteration is:
# [300]	valid's auc: 0.869277
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866692
# [200]	valid's auc: 0.868238
# [300]	valid's auc: 0.869064
# Early stopping, best iteration is:
# [299]	valid's auc: 0.869065
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866659
# [200]	valid's auc: 0.868243
# Early stopping, best iteration is:
# [241]	valid's auc: 0.868579
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.86693
# [200]	valid's auc: 0.868648
# Early stopping, best iteration is:
# [212]	valid's auc: 0.868727
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.866809
# [200]	valid's auc: 0.868522
# Early stopping, best iteration is:
# [204]	valid's auc: 0.868575
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864727
# [200]	valid's auc: 0.866921
# [300]	valid's auc: 0.86769
# [400]	valid's auc: 0.867979
# [500]	valid's auc: 0.868294
# Early stopping, best iteration is:
# [470]	valid's auc: 0.868311
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.863803
# [200]	valid's auc: 0.865953
# [300]	valid's auc: 0.866801
# [400]	valid's auc: 0.867506
# [500]	valid's auc: 0.86784
# Early stopping, best iteration is:
# [539]	valid's auc: 0.867948
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864421
# [200]	valid's auc: 0.866474
# [300]	valid's auc: 0.867065
# [400]	valid's auc: 0.867556
# Early stopping, best iteration is:
# [387]	valid's auc: 0.867575
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864475
# [200]	valid's auc: 0.866242
# [300]	valid's auc: 0.86737
# [400]	valid's auc: 0.867686
# Early stopping, best iteration is:
# [413]	valid's auc: 0.867731
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.863774
# [200]	valid's auc: 0.86591
# [300]	valid's auc: 0.866971
# [400]	valid's auc: 0.867459
# [500]	valid's auc: 0.867626
# Early stopping, best iteration is:
# [493]	valid's auc: 0.867626
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.86409
# [200]	valid's auc: 0.866166
# [300]	valid's auc: 0.866972
# [400]	valid's auc: 0.867568
# [500]	valid's auc: 0.867778
# Early stopping, best iteration is:
# [482]	valid's auc: 0.867798
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864451
# [200]	valid's auc: 0.866747
# [300]	valid's auc: 0.867673
# [400]	valid's auc: 0.868337
# [500]	valid's auc: 0.86857
# Early stopping, best iteration is:
# [477]	valid's auc: 0.868581
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.863645
# [200]	valid's auc: 0.866306
# [300]	valid's auc: 0.867349
# [400]	valid's auc: 0.86794
# [500]	valid's auc: 0.868232
# [600]	valid's auc: 0.868407
# Early stopping, best iteration is:
# [573]	valid's auc: 0.868418
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.863872
# [200]	valid's auc: 0.866436
# [300]	valid's auc: 0.867229
# [400]	valid's auc: 0.867631
# [500]	valid's auc: 0.867886
# Early stopping, best iteration is:
# [488]	valid's auc: 0.86791
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864766
# [200]	valid's auc: 0.86649
# [300]	valid's auc: 0.867664
# [400]	valid's auc: 0.867943
# Early stopping, best iteration is:
# [430]	valid's auc: 0.868025
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864198
# [200]	valid's auc: 0.866348
# [300]	valid's auc: 0.867129
# [400]	valid's auc: 0.8679
# Early stopping, best iteration is:
# [454]	valid's auc: 0.8682
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864567
# [200]	valid's auc: 0.866763
# [300]	valid's auc: 0.867914
# Early stopping, best iteration is:
# [366]	valid's auc: 0.868373
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864526
# [200]	valid's auc: 0.866406
# [300]	valid's auc: 0.86722
# Early stopping, best iteration is:
# [359]	valid's auc: 0.867374
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.863732
# [200]	valid's auc: 0.866343
# [300]	valid's auc: 0.867096
# [400]	valid's auc: 0.867416
# [500]	valid's auc: 0.867626
# Early stopping, best iteration is:
# [484]	valid's auc: 0.867693
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.863456
# [200]	valid's auc: 0.865727
# [300]	valid's auc: 0.866567
# [400]	valid's auc: 0.86703
# [500]	valid's auc: 0.86747
# Early stopping, best iteration is:
# [495]	valid's auc: 0.867568
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864581
# [200]	valid's auc: 0.866352
# [300]	valid's auc: 0.867015
# [400]	valid's auc: 0.867624
# [500]	valid's auc: 0.86778
# Early stopping, best iteration is:
# [483]	valid's auc: 0.867918
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.863701
# [200]	valid's auc: 0.865511
# [300]	valid's auc: 0.866245
# [400]	valid's auc: 0.866733
# Early stopping, best iteration is:
# [385]	valid's auc: 0.866797
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864215
# [200]	valid's auc: 0.866041
# [300]	valid's auc: 0.866953
# Early stopping, best iteration is:
# [312]	valid's auc: 0.867196
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.860811
# [200]	valid's auc: 0.863439
# [300]	valid's auc: 0.864468
# [400]	valid's auc: 0.865124
# [500]	valid's auc: 0.865689
# [600]	valid's auc: 0.866016
# [700]	valid's auc: 0.866379
# [800]	valid's auc: 0.866664
# Early stopping, best iteration is:
# [800]	valid's auc: 0.866664
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.860474
# [200]	valid's auc: 0.863068
# [300]	valid's auc: 0.86384
# [400]	valid's auc: 0.864475
# [500]	valid's auc: 0.864897
# [600]	valid's auc: 0.865326
# [700]	valid's auc: 0.865737
# Early stopping, best iteration is:
# [715]	valid's auc: 0.86582
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.86057
# [200]	valid's auc: 0.863197
# [300]	valid's auc: 0.864226
# [400]	valid's auc: 0.864938
# [500]	valid's auc: 0.865356
# [600]	valid's auc: 0.865767
# [700]	valid's auc: 0.865959
# Early stopping, best iteration is:
# [752]	valid's auc: 0.866047
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.865372
# [200]	valid's auc: 0.867244
# [300]	valid's auc: 0.868086
# [400]	valid's auc: 0.868757
# [500]	valid's auc: 0.869473
# [600]	valid's auc: 0.869929
# Early stopping, best iteration is:
# [578]	valid's auc: 0.86995
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.865203
# [200]	valid's auc: 0.866893
# [300]	valid's auc: 0.867884
# [400]	valid's auc: 0.868398
# Early stopping, best iteration is:
# [408]	valid's auc: 0.868428
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.8646
# [200]	valid's auc: 0.866935
# [300]	valid's auc: 0.867755
# [400]	valid's auc: 0.868395
# Early stopping, best iteration is:
# [434]	valid's auc: 0.868572
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.863796
# [200]	valid's auc: 0.866053
# [300]	valid's auc: 0.866622
# [400]	valid's auc: 0.867138
# [500]	valid's auc: 0.867441
# Early stopping, best iteration is:
# [565]	valid's auc: 0.867785
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.862973
# [200]	valid's auc: 0.865303
# [300]	valid's auc: 0.866255
# [400]	valid's auc: 0.866739
# Early stopping, best iteration is:
# [385]	valid's auc: 0.866839
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.863015
# [200]	valid's auc: 0.86553
# [300]	valid's auc: 0.866362
# [400]	valid's auc: 0.866716
# [500]	valid's auc: 0.867273
# [600]	valid's auc: 0.867478
# Early stopping, best iteration is:
# [602]	valid's auc: 0.867543
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.865413
# [200]	valid's auc: 0.867041
# [300]	valid's auc: 0.867691
# Early stopping, best iteration is:
# [313]	valid's auc: 0.867911
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.864858
# [200]	valid's auc: 0.866636
# [300]	valid's auc: 0.867419
# Early stopping, best iteration is:
# [362]	valid's auc: 0.867731
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.865232
# [200]	valid's auc: 0.866672
# [300]	valid's auc: 0.867258
# [400]	valid's auc: 0.867666
# Early stopping, best iteration is:
# [405]	valid's auc: 0.867713
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.862588
# [200]	valid's auc: 0.864935
# [300]	valid's auc: 0.866159
# [400]	valid's auc: 0.866704
# [500]	valid's auc: 0.867107
# [600]	valid's auc: 0.867472
# [700]	valid's auc: 0.867802
# [800]	valid's auc: 0.868082
# [900]	valid's auc: 0.868319
# Early stopping, best iteration is:
# [929]	valid's auc: 0.868356
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.8625
# [200]	valid's auc: 0.864844
# [300]	valid's auc: 0.86578
# [400]	valid's auc: 0.866185
# [500]	valid's auc: 0.866525
# [600]	valid's auc: 0.867122
# [700]	valid's auc: 0.867363
# [800]	valid's auc: 0.867469
# Early stopping, best iteration is:
# [780]	valid's auc: 0.867513
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.862605
# [200]	valid's auc: 0.865028
# [300]	valid's auc: 0.865964
# [400]	valid's auc: 0.866448
# [500]	valid's auc: 0.866936
# [600]	valid's auc: 0.867185
# [700]	valid's auc: 0.867481
# [800]	valid's auc: 0.867754
# Early stopping, best iteration is:
# [837]	valid's auc: 0.867882
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed: 50.9min finished
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.869727
# [200]	valid's auc: 0.872551
# [300]	valid's auc: 0.874022
# [400]	valid's auc: 0.875265
# [500]	valid's auc: 0.876093
# [600]	valid's auc: 0.876759
# [700]	valid's auc: 0.877503
# [800]	valid's auc: 0.877977
# [900]	valid's auc: 0.878361
# Early stopping, best iteration is:
# [913]	valid's auc: 0.87841
# Best score reached: 0.8724027449215775 with params: {'colsample_bytree': 0.8665631328558623, 'min_child_samples': 122, 'min_child_weight': 0.1, 'num_leaves': 48, 'reg_alpha': 2, 'reg_lambda': 50, 'subsample': 0.7252600946741159}

# %%
opt_parameters = {'colsample_bytree': 0.8665631328558623, 'min_child_samples': 122, 'min_child_weight': 0.1, 'num_leaves': 48, 'reg_alpha': 2, 'reg_lambda': 50, 'subsample': 0.7252600946741159}

# %%
clf_sw = lgb.LGBMClassifier(**clf.get_params())
#set optimal parameters
clf_sw.set_params(**opt_parameters)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                colsample_bytree=0.8665631328558623, importance_type='split',
#                learning_rate=0.1, max_depth=-1, metric='None',
#                min_child_samples=122, min_child_weight=0.1, min_split_gain=0.0,
#                n_estimators=5000, n_jobs=4, num_leaves=48, objective=None,
#                random_state=314, reg_alpha=2, reg_lambda=50, silent=True,
#                subsample=0.7252600946741159, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
clf_sw.fit(X_train, y_train, **fit_params, callbacks=[lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_0995)])
# Out:
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.868707
# [200]	valid's auc: 0.870869
# [300]	valid's auc: 0.871713
# [400]	valid's auc: 0.872077
# [500]	valid's auc: 0.872242
# [600]	valid's auc: 0.872405
# [700]	valid's auc: 0.872475
# [800]	valid's auc: 0.872514
# [900]	valid's auc: 0.872548
# [1000]	valid's auc: 0.872563
# [1100]	valid's auc: 0.872574
# Early stopping, best iteration is:
# [1103]	valid's auc: 0.872574
# LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                colsample_bytree=0.8665631328558623, importance_type='split',
#                learning_rate=0.1, max_depth=-1, metric='None',
#                min_child_samples=122, min_child_weight=0.1, min_split_gain=0.0,
#                n_estimators=5000, n_jobs=4, num_leaves=48, objective=None,
#                random_state=314, reg_alpha=2, reg_lambda=50, silent=True,
#                subsample=0.7252600946741159, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
#Configure locally from hardcoded values
#clf_final = lgb.LGBMClassifier(**clf.get_params())
#set optimal parameters
#clf_final.set_params(**opt_parameters)

#Train the final model with learning rate decay
#clf_final.fit(X_train, y_train, **fit_params, callbacks=[lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_0995)])

# %%
y_pred = clf_sw.predict(X_test)

# %%
X_test.columns
# Out:
# Index(['Var1', 'Var2', 'Var3', 'Var4', 'Var5', 'Category3', 'Online_Follower',
#        'LinkedIn_Shared', 'Twitter_Shared', 'Facebook_Shared',
#        ...
#        'Employer_Category_Food', 'Employer_Category_Health',
#        'Employer_Category_Manufacturing', 'Employer_Category_Others',
#        'Employer_Category_Real Estate', 'Employer_Category_Retail',
#        'Employer_Category_Software Industry', 'Employer_Category_Technology',
#        'Employer_Category_Telecom', 'Employer_Category_Transport'],
#       dtype='object', length=147)

# %%
set(X.columns) - set(X_test.columns)
# Out:
# set()

# %%
submission_df = test_final_data.copy()
submission_df['Outcome'] = y_pred
submission_df = submission_df[['Patient_ID', 'Health_Camp_ID','Outcome']]
submission_df.to_csv('submission_1st_attempt.csv', index=False)

# %%
from google.colab import files
files.download("submission_1st_attempt.csv")
